# %% [markdown]
# ## Spacy tutorial

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML

# %%
# %%cmd
# python -m spacy download en
# Out:
# Microsoft Windows [Version 10.0.16299.248]
# (c) 2017 Microsoft Corporation. All rights reserved.
#
# C:\Users\john\Programming\Research\central-bank-nlp>python -m spacy download en
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#   Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages
# Requirement already satisfied: spacy>=2.0.0a18 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from en-core-web-sm==2.0.0)
# Requirement already satisfied: numpy>=1.7 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: six in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: pathlib in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: ujson>=1.35 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: regex==2017.4.5 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: msgpack-python in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: msgpack-numpy==0.4.1 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: wrapt in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: termcolor in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: pyreadline>=1.7.1 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from dill<0.3,>=0.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: html5lib in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: wcwidth in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\john\appdata\local\continuum\anaconda3\lib\site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
#
#     Error: Couldn't link model to 'en'
#     Creating a symlink in spacy/data failed. Make sure you have the required
#     permissions and try re-running the command as admin, or use a
#     virtualenv. You can still import the model as a module and call its
#     load() method, or create the symlink manually.
#
#     C:\Users\john\AppData\Local\Continuum\anaconda3\lib\site-packages\en_core_web_sm
#     -->
#     C:\Users\john\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\data\en
#
#
#     Download successful
#     Creating a shortcut link for 'en' didn't work (maybe you don't have
#     admin permissions?), but you can still load the model via its full
#     package name:
#
#     nlp = spacy.load('en_core_web_sm')
#
#
# C:\Users\john\Programming\Research\central-bank-nlp>

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = open('nz-central-bank/official-cash-rate/2006-01-26.txt', 'r').read()
text1 = open('nz-central-bank/official-cash-rate/2011-12-08.txt', 'r').read()

# %%
doc = nlp(text)
doc1 = nlp(text1)

# %% [markdown]
# #### Tokenizing text

# %%
for token in doc:
    print(token, token.pos_)
# Out:
# The DET
# Official ADJ
# Cash PROPN
# Rate PROPN
# ( PUNCT
# OCR PROPN
# ) PUNCT
# will VERB
# remain VERB
# unchanged ADJ
# at ADP
# 7.25 NUM
# percent NOUN
# . PUNCT
#
#
#  SPACE
# Reserve PROPN
# Bank PROPN
# Governor PROPN
# Alan PROPN
# Bollard PROPN
# said VERB
# : PUNCT
# " PUNCT
# The DET
# economy NOUN
# has VERB
# continued VERB
# to PART
# slow VERB
# in ADP
# recent ADJ
# months NOUN
# , PUNCT
# broadly ADV
# in ADP
# line NOUN
# with ADP
# the DET
# outlook NOUN
# contained VERB
# in ADP
# our ADJ
# December PROPN
# Monetary PROPN
# Policy PROPN
# Statement PROPN
# . PUNCT
#
#  SPACE
# GDP PROPN
# growth NOUN
# slowed VERB
# in ADP
# the DET
# third ADJ
# quarter NOUN
# of ADP
# 2005 NUM
# , PUNCT
# due ADP
# to ADP
# the DET
# impact NOUN
# of ADP
# the DET
# high ADJ
# exchange NOUN
# rate NOUN
# on ADP
# the DET
# export NOUN
# and CCONJ
# import NOUN
# - PUNCT
# competing VERB
# sectors NOUN
# , PUNCT
# and CCONJ
# a DET
# fall NOUN
# in ADP
# construction NOUN
# . PUNCT
#
#  SPACE
# Looking VERB
# to ADP
# 2006 NUM
# , PUNCT
# while ADP
# there ADV
# are VERB
# some DET
# early ADJ
# indications NOUN
# , PUNCT
# we PRON
# are VERB
# yet ADV
# to PART
# see VERB
# hard ADJ
# evidence NOUN
# of ADP
# a DET
# sustained ADJ
# slowdown NOUN
# in ADP
# domestic ADJ
# demand NOUN
# . PUNCT
#
#  SPACE
# To ADP
# date NOUN
# , PUNCT
# strong ADJ
# domestic ADJ
# demand NOUN
# has VERB
# been VERB
# fuelled VERB
# by ADP
# strong ADJ
# employment NOUN
# , PUNCT
# wage NOUN
# growth NOUN
# , PUNCT
# rising VERB
# house NOUN
# prices NOUN
# , PUNCT
# and CCONJ
# growth NOUN
# in ADP
# Government PROPN
# spending NOUN
# . PUNCT
#
#  SPACE
# Overall ADJ
# , PUNCT
# total ADJ
# spending NOUN
# continues VERB
# to PART
# outstrip VERB
# growth NOUN
# in ADP
# production NOUN
# , PUNCT
# contributing VERB
# to ADP
# an DET
# unsustainably ADV
# large ADJ
# current ADJ
# account NOUN
# deficit NOUN
# . PUNCT
#
#
#  SPACE
# " PUNCT
# Over ADP
# recent ADJ
# years NOUN
# , PUNCT
# considerable ADJ
# pressures NOUN
# have VERB
# built VERB
# up PART
# on ADP
# resources NOUN
# , PUNCT
# leading VERB
# to ADP
# the DET
# current ADJ
# high ADJ
# level NOUN
# of ADP
# inflation NOUN
# . PUNCT
#
#  SPACE
# While ADP
# capacity NOUN
# and CCONJ
# resource NOUN
# constraints NOUN
# appear VERB
# now ADV
# to PART
# be VERB
# easing VERB
# , PUNCT
# inflation NOUN
# pressures NOUN
# remain VERB
# of ADP
# concern NOUN
# . PUNCT
#
#  SPACE
# Annual PROPN
# CPI PROPN
# inflation NOUN
# stands VERB
# at ADP
# 3.2 NUM
# percent NOUN
# , PUNCT
# and CCONJ
# our ADJ
# forecasts NOUN
# point NOUN
# to ADP
# inflation NOUN
# remaining VERB
# toward ADP
# the DET
# upper ADJ
# end NOUN
# of ADP
# the DET
# target NOUN
# band NOUN
# over ADP
# the DET
# next ADJ
# couple NOUN
# of ADP
# years NOUN
# . PUNCT
#
#  SPACE
# Continuing PROPN
# increases NOUN
# in ADP
# wages NOUN
# , PUNCT
# energy NOUN
# prices NOUN
# and CCONJ
# other ADJ
# business NOUN
# costs NOUN
# suggest VERB
# that ADP
# inflation NOUN
# pressures NOUN
# will VERB
# not ADV
# subside VERB
# quickly ADV
# . PUNCT
#
#  SPACE
# Of ADP
# particular ADJ
# concern NOUN
# , PUNCT
# inflation NOUN
# expectations NOUN
# remain VERB
# uncomfortably ADV
# high ADJ
# . PUNCT
#
#
#  SPACE
# " PUNCT
# Given VERB
# this DET
# situation NOUN
# , PUNCT
# we PRON
# do VERB
# not ADV
# expect VERB
# to PART
# raise VERB
# the DET
# OCR PROPN
# further ADV
# in ADP
# this DET
# cycle NOUN
# ; PUNCT
# however ADV
# , PUNCT
# this DET
# possibility NOUN
# can VERB
# not ADV
# be VERB
# ruled VERB
# out PART
# until ADP
# we PRON
# see VERB
# clear ADJ
# evidence NOUN
# of ADP
# a DET
# sustained ADJ
# weakening NOUN
# in ADP
# domestic ADJ
# demand NOUN
# . PUNCT
#
#  SPACE
# Certainly ADV
# we PRON
# see VERB
# no DET
# prospect NOUN
# of ADP
# an DET
# OCR PROPN
# easing NOUN
# , PUNCT
# given VERB
# the DET
# relatively ADV
# high ADJ
# medium ADJ
# - PUNCT
# term NOUN
# inflation NOUN
# outlook NOUN
# . PUNCT
#
#  SPACE
# An DET
# early ADJ
# decline NOUN
# in ADP
# interest NOUN
# rates NOUN
# , PUNCT
# as ADP
# expected VERB
# by ADP
# some DET
# in ADP
# the DET
# financial ADJ
# markets NOUN
# , PUNCT
# would VERB
# risk VERB
# reigniting VERB
# spending NOUN
# and CCONJ
# hence ADV
# inflation NOUN
# pressures NOUN
# . PUNCT
# " PUNCT

# %% [markdown]
# ### Splitting text into sentences

# %%
for sent in doc.sents:
    print([(token, token.pos_) for token in sent])
# Out:
# [(The, 'DET'), (Official, 'ADJ'), (Cash, 'PROPN'), (Rate, 'PROPN'), ((, 'PUNCT'), (OCR, 'PROPN'), (), 'PUNCT'), (will, 'VERB'), (remain, 'VERB'), (unchanged, 'ADJ'), (at, 'ADP'), (7.25, 'NUM'), (percent, 'NOUN'), (., 'PUNCT'), (
#
# , 'SPACE')]
# [(Reserve, 'PROPN'), (Bank, 'PROPN'), (Governor, 'PROPN'), (Alan, 'PROPN'), (Bollard, 'PROPN'), (said, 'VERB'), (:, 'PUNCT'), (", 'PUNCT'), (The, 'DET'), (economy, 'NOUN'), (has, 'VERB'), (continued, 'VERB'), (to, 'PART'), (slow, 'VERB'), (in, 'ADP'), (recent, 'ADJ'), (months, 'NOUN'), (,, 'PUNCT'), (broadly, 'ADV'), (in, 'ADP'), (line, 'NOUN'), (with, 'ADP'), (the, 'DET'), (outlook, 'NOUN'), (contained, 'VERB'), (in, 'ADP'), (our, 'ADJ'), (December, 'PROPN'), (Monetary, 'PROPN'), (Policy, 'PROPN'), (Statement, 'PROPN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(GDP, 'PROPN'), (growth, 'NOUN'), (slowed, 'VERB'), (in, 'ADP'), (the, 'DET'), (third, 'ADJ'), (quarter, 'NOUN'), (of, 'ADP'), (2005, 'NUM'), (,, 'PUNCT'), (due, 'ADP'), (to, 'ADP'), (the, 'DET'), (impact, 'NOUN'), (of, 'ADP'), (the, 'DET'), (high, 'ADJ'), (exchange, 'NOUN'), (rate, 'NOUN'), (on, 'ADP'), (the, 'DET'), (export, 'NOUN'), (and, 'CCONJ'), (import, 'NOUN'), (-, 'PUNCT'), (competing, 'VERB'), (sectors, 'NOUN'), (,, 'PUNCT'), (and, 'CCONJ'), (a, 'DET'), (fall, 'NOUN'), (in, 'ADP'), (construction, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Looking, 'VERB'), (to, 'ADP'), (2006, 'NUM'), (,, 'PUNCT'), (while, 'ADP'), (there, 'ADV'), (are, 'VERB'), (some, 'DET'), (early, 'ADJ'), (indications, 'NOUN'), (,, 'PUNCT'), (we, 'PRON'), (are, 'VERB'), (yet, 'ADV'), (to, 'PART'), (see, 'VERB'), (hard, 'ADJ'), (evidence, 'NOUN'), (of, 'ADP'), (a, 'DET'), (sustained, 'ADJ'), (slowdown, 'NOUN'), (in, 'ADP'), (domestic, 'ADJ'), (demand, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(To, 'ADP'), (date, 'NOUN'), (,, 'PUNCT'), (strong, 'ADJ'), (domestic, 'ADJ'), (demand, 'NOUN'), (has, 'VERB'), (been, 'VERB'), (fuelled, 'VERB'), (by, 'ADP'), (strong, 'ADJ'), (employment, 'NOUN'), (,, 'PUNCT'), (wage, 'NOUN'), (growth, 'NOUN'), (,, 'PUNCT'), (rising, 'VERB'), (house, 'NOUN'), (prices, 'NOUN'), (,, 'PUNCT'), (and, 'CCONJ'), (growth, 'NOUN'), (in, 'ADP'), (Government, 'PROPN'), (spending, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Overall, 'ADJ'), (,, 'PUNCT'), (total, 'ADJ'), (spending, 'NOUN'), (continues, 'VERB'), (to, 'PART'), (outstrip, 'VERB'), (growth, 'NOUN'), (in, 'ADP'), (production, 'NOUN'), (,, 'PUNCT'), (contributing, 'VERB'), (to, 'ADP'), (an, 'DET'), (unsustainably, 'ADV'), (large, 'ADJ'), (current, 'ADJ'), (account, 'NOUN'), (deficit, 'NOUN'), (., 'PUNCT'), (
#
# , 'SPACE')]
# [(", 'PUNCT'), (Over, 'ADP'), (recent, 'ADJ'), (years, 'NOUN'), (,, 'PUNCT'), (considerable, 'ADJ'), (pressures, 'NOUN'), (have, 'VERB'), (built, 'VERB'), (up, 'PART'), (on, 'ADP'), (resources, 'NOUN'), (,, 'PUNCT'), (leading, 'VERB'), (to, 'ADP'), (the, 'DET'), (current, 'ADJ'), (high, 'ADJ'), (level, 'NOUN'), (of, 'ADP'), (inflation, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(While, 'ADP'), (capacity, 'NOUN'), (and, 'CCONJ'), (resource, 'NOUN'), (constraints, 'NOUN'), (appear, 'VERB'), (now, 'ADV'), (to, 'PART'), (be, 'VERB'), (easing, 'VERB'), (,, 'PUNCT'), (inflation, 'NOUN'), (pressures, 'NOUN'), (remain, 'VERB'), (of, 'ADP'), (concern, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Annual, 'PROPN'), (CPI, 'PROPN'), (inflation, 'NOUN'), (stands, 'VERB'), (at, 'ADP'), (3.2, 'NUM'), (percent, 'NOUN'), (,, 'PUNCT'), (and, 'CCONJ'), (our, 'ADJ'), (forecasts, 'NOUN'), (point, 'NOUN'), (to, 'ADP'), (inflation, 'NOUN'), (remaining, 'VERB'), (toward, 'ADP'), (the, 'DET'), (upper, 'ADJ'), (end, 'NOUN'), (of, 'ADP'), (the, 'DET'), (target, 'NOUN'), (band, 'NOUN'), (over, 'ADP'), (the, 'DET'), (next, 'ADJ'), (couple, 'NOUN'), (of, 'ADP'), (years, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Continuing, 'PROPN'), (increases, 'NOUN'), (in, 'ADP'), (wages, 'NOUN'), (,, 'PUNCT'), (energy, 'NOUN'), (prices, 'NOUN'), (and, 'CCONJ'), (other, 'ADJ'), (business, 'NOUN'), (costs, 'NOUN'), (suggest, 'VERB'), (that, 'ADP'), (inflation, 'NOUN'), (pressures, 'NOUN'), (will, 'VERB'), (not, 'ADV'), (subside, 'VERB'), (quickly, 'ADV'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Of, 'ADP'), (particular, 'ADJ'), (concern, 'NOUN'), (,, 'PUNCT'), (inflation, 'NOUN'), (expectations, 'NOUN'), (remain, 'VERB'), (uncomfortably, 'ADV'), (high, 'ADJ'), (., 'PUNCT'), (
#
# , 'SPACE')]
# [(", 'PUNCT'), (Given, 'VERB'), (this, 'DET'), (situation, 'NOUN'), (,, 'PUNCT'), (we, 'PRON'), (do, 'VERB'), (not, 'ADV'), (expect, 'VERB'), (to, 'PART'), (raise, 'VERB'), (the, 'DET'), (OCR, 'PROPN'), (further, 'ADV'), (in, 'ADP'), (this, 'DET'), (cycle, 'NOUN'), (;, 'PUNCT'), (however, 'ADV'), (,, 'PUNCT'), (this, 'DET'), (possibility, 'NOUN'), (can, 'VERB'), (not, 'ADV'), (be, 'VERB'), (ruled, 'VERB'), (out, 'PART'), (until, 'ADP'), (we, 'PRON'), (see, 'VERB'), (clear, 'ADJ'), (evidence, 'NOUN'), (of, 'ADP'), (a, 'DET'), (sustained, 'ADJ'), (weakening, 'NOUN'), (in, 'ADP'), (domestic, 'ADJ'), (demand, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(Certainly, 'ADV'), (we, 'PRON'), (see, 'VERB'), (no, 'DET'), (prospect, 'NOUN'), (of, 'ADP'), (an, 'DET'), (OCR, 'PROPN'), (easing, 'NOUN'), (,, 'PUNCT'), (given, 'VERB'), (the, 'DET'), (relatively, 'ADV'), (high, 'ADJ'), (medium, 'ADJ'), (-, 'PUNCT'), (term, 'NOUN'), (inflation, 'NOUN'), (outlook, 'NOUN'), (., 'PUNCT'), (
# , 'SPACE')]
# [(An, 'DET'), (early, 'ADJ'), (decline, 'NOUN'), (in, 'ADP'), (interest, 'NOUN'), (rates, 'NOUN'), (,, 'PUNCT'), (as, 'ADP'), (expected, 'VERB'), (by, 'ADP'), (some, 'DET'), (in, 'ADP'), (the, 'DET'), (financial, 'ADJ'), (markets, 'NOUN'), (,, 'PUNCT'), (would, 'VERB'), (risk, 'VERB'), (reigniting, 'VERB'), (spending, 'NOUN'), (and, 'CCONJ'), (hence, 'ADV'), (inflation, 'NOUN'), (pressures, 'NOUN'), (., 'PUNCT'), (", 'PUNCT')]

# %% [markdown]
# ### Part-of-speech tagging and dependency parsing

# %%
for token in doc:
    print(token, token.pos_, token.dep_, token.head)
# Out:
# The DET det Rate
# Official ADJ compound Rate
# Cash PROPN compound Rate
# Rate PROPN nsubj remain
# ( PUNCT punct OCR
# OCR PROPN appos Rate
# ) PUNCT punct OCR
# will VERB aux remain
# remain VERB ROOT remain
# unchanged ADJ acomp remain
# at ADP prep remain
# 7.25 NUM nummod percent
# percent NOUN pobj at
# . PUNCT punct remain
#
#
#  SPACE  .
# Reserve PROPN compound Bank
# Bank PROPN compound Governor
# Governor PROPN compound Bollard
# Alan PROPN compound Bollard
# Bollard PROPN nsubj said
# said VERB ROOT said
# : PUNCT punct said
# " PUNCT punct said
# The DET det economy
# economy NOUN nsubj continued
# has VERB aux continued
# continued VERB ccomp said
# to PART aux slow
# slow VERB xcomp continued
# in ADP prep slow
# recent ADJ amod months
# months NOUN pobj in
# , PUNCT punct slow
# broadly ADV advmod in
# in ADP prep slow
# line NOUN pobj in
# with ADP prep line
# the DET det outlook
# outlook NOUN pobj with
# contained VERB acl outlook
# in ADP prep contained
# our ADJ poss Statement
# December PROPN compound Statement
# Monetary PROPN compound Policy
# Policy PROPN compound Statement
# Statement PROPN pobj in
# . PUNCT punct said
#
#  SPACE  .
# GDP PROPN compound growth
# growth NOUN nsubj slowed
# slowed VERB ROOT slowed
# in ADP prep slowed
# the DET det quarter
# third ADJ amod quarter
# quarter NOUN pobj in
# of ADP prep quarter
# 2005 NUM pobj of
# , PUNCT punct slowed
# due ADP prep slowed
# to ADP pcomp due
# the DET det impact
# impact NOUN pobj due
# of ADP prep impact
# the DET det rate
# high ADJ amod exchange
# exchange NOUN compound rate
# rate NOUN pobj of
# on ADP prep rate
# the DET det sectors
# export NOUN nmod sectors
# and CCONJ cc export
# import NOUN npadvmod competing
# - PUNCT punct competing
# competing VERB conj export
# sectors NOUN pobj on
# , PUNCT punct slowed
# and CCONJ cc slowed
# a DET det fall
# fall NOUN conj slowed
# in ADP prep fall
# construction NOUN pobj in
# . PUNCT punct slowed
#
#  SPACE  .
# Looking VERB advcl are
# to ADP prep Looking
# 2006 NUM pobj to
# , PUNCT punct Looking
# while ADP mark are
# there ADV expl are
# are VERB advcl Looking
# some DET det indications
# early ADJ amod indications
# indications NOUN attr are
# , PUNCT punct are
# we PRON nsubj are
# are VERB ROOT are
# yet ADV advmod are
# to PART aux see
# see VERB xcomp are
# hard ADJ amod evidence
# evidence NOUN dobj see
# of ADP prep evidence
# a DET det slowdown
# sustained ADJ amod slowdown
# slowdown NOUN pobj of
# in ADP prep slowdown
# domestic ADJ amod demand
# demand NOUN pobj in
# . PUNCT punct are
#
#  SPACE  .
# To ADP prep fuelled
# date NOUN pobj To
# , PUNCT punct fuelled
# strong ADJ amod demand
# domestic ADJ amod demand
# demand NOUN nsubjpass fuelled
# has VERB aux fuelled
# been VERB auxpass fuelled
# fuelled VERB ROOT fuelled
# by ADP agent fuelled
# strong ADJ amod employment
# employment NOUN pobj by
# , PUNCT punct employment
# wage NOUN compound growth
# growth NOUN conj employment
# , PUNCT punct growth
# rising VERB amod prices
# house NOUN compound prices
# prices NOUN conj growth
# , PUNCT punct prices
# and CCONJ cc prices
# growth NOUN conj prices
# in ADP prep growth
# Government PROPN compound spending
# spending NOUN pobj in
# . PUNCT punct fuelled
#
#  SPACE  .
# Overall ADJ advmod continues
# , PUNCT punct continues
# total ADJ amod spending
# spending NOUN nsubj continues
# continues VERB ROOT continues
# to PART aux outstrip
# outstrip VERB xcomp continues
# growth NOUN dobj outstrip
# in ADP prep growth
# production NOUN pobj in
# , PUNCT punct outstrip
# contributing VERB advcl outstrip
# to ADP prep contributing
# an DET det deficit
# unsustainably ADV advmod large
# large ADJ amod deficit
# current ADJ amod deficit
# account NOUN compound deficit
# deficit NOUN pobj to
# . PUNCT punct continues
#
#
#  SPACE  .
# " PUNCT punct built
# Over ADP prep built
# recent ADJ amod years
# years NOUN pobj Over
# , PUNCT punct built
# considerable ADJ amod pressures
# pressures NOUN nsubj built
# have VERB aux built
# built VERB ROOT built
# up PART prt built
# on ADP prep built
# resources NOUN pobj on
# , PUNCT punct built
# leading VERB advcl built
# to ADP prep leading
# the DET det level
# current ADJ amod level
# high ADJ amod level
# level NOUN pobj to
# of ADP prep level
# inflation NOUN pobj of
# . PUNCT punct built
#
#  SPACE  .
# While ADP mark appear
# capacity NOUN nmod constraints
# and CCONJ cc capacity
# resource NOUN conj capacity
# constraints NOUN nsubj appear
# appear VERB advcl remain
# now ADV advmod appear
# to PART aux easing
# be VERB aux easing
# easing VERB xcomp appear
# , PUNCT punct remain
# inflation NOUN compound pressures
# pressures NOUN nsubj remain
# remain VERB ROOT remain
# of ADP prep remain
# concern NOUN pobj of
# . PUNCT punct remain
#
#  SPACE  .
# Annual PROPN amod inflation
# CPI PROPN compound inflation
# inflation NOUN nsubj stands
# stands VERB ROOT stands
# at ADP prep stands
# 3.2 NUM nummod percent
# percent NOUN pobj at
# , PUNCT punct stands
# and CCONJ cc stands
# our ADJ poss forecasts
# forecasts NOUN nsubj point
# point NOUN conj stands
# to ADP prep point
# inflation NOUN pobj to
# remaining VERB advcl point
# toward ADP prep remaining
# the DET det end
# upper ADJ amod end
# end NOUN pobj toward
# of ADP prep end
# the DET det band
# target NOUN compound band
# band NOUN pobj of
# over ADP prep remaining
# the DET det couple
# next ADJ amod couple
# couple NOUN pobj over
# of ADP prep couple
# years NOUN pobj of
# . PUNCT punct point
#
#  SPACE  .
# Continuing PROPN amod increases
# increases NOUN nsubj suggest
# in ADP prep increases
# wages NOUN pobj in
# , PUNCT punct increases
# energy NOUN compound prices
# prices NOUN conj increases
# and CCONJ cc prices
# other ADJ amod costs
# business NOUN compound costs
# costs NOUN conj prices
# suggest VERB ROOT suggest
# that ADP mark subside
# inflation NOUN compound pressures
# pressures NOUN nsubj subside
# will VERB aux subside
# not ADV neg subside
# subside VERB ccomp suggest
# quickly ADV advmod subside
# . PUNCT punct suggest
#
#  SPACE  .
# Of ADP prep remain
# particular ADJ amod concern
# concern NOUN pobj Of
# , PUNCT punct remain
# inflation NOUN compound expectations
# expectations NOUN nsubj remain
# remain VERB ROOT remain
# uncomfortably ADV advmod high
# high ADJ acomp remain
# . PUNCT punct remain
#
#
#  SPACE  .
# " PUNCT punct expect
# Given VERB prep expect
# this DET det situation
# situation NOUN pobj Given
# , PUNCT punct expect
# we PRON nsubj expect
# do VERB aux expect
# not ADV neg expect
# expect VERB ccomp ruled
# to PART aux raise
# raise VERB xcomp expect
# the DET det OCR
# OCR PROPN dobj raise
# further ADV advmod raise
# in ADP prep raise
# this DET det cycle
# cycle NOUN pobj in
# ; PUNCT punct ruled
# however ADV advmod ruled
# , PUNCT punct ruled
# this DET det possibility
# possibility NOUN nsubjpass ruled
# can VERB aux ruled
# not ADV neg ruled
# be VERB auxpass ruled
# ruled VERB ROOT ruled
# out PART prt ruled
# until ADP mark see
# we PRON nsubj see
# see VERB advcl ruled
# clear ADJ amod evidence
# evidence NOUN dobj see
# of ADP prep evidence
# a DET det weakening
# sustained ADJ amod weakening
# weakening NOUN pobj of
# in ADP prep weakening
# domestic ADJ amod demand
# demand NOUN pobj in
# . PUNCT punct ruled
#
#  SPACE  .
# Certainly ADV advmod see
# we PRON nsubj see
# see VERB ROOT see
# no DET det prospect
# prospect NOUN dobj see
# of ADP prep prospect
# an DET det easing
# OCR PROPN compound easing
# easing NOUN pobj of
# , PUNCT punct see
# given VERB prep see
# the DET det outlook
# relatively ADV advmod high
# high ADJ amod outlook
# medium ADJ amod term
# - PUNCT punct term
# term NOUN compound outlook
# inflation NOUN compound outlook
# outlook NOUN pobj given
# . PUNCT punct see
#
#  SPACE  .
# An DET det decline
# early ADJ amod decline
# decline NOUN nsubj risk
# in ADP prep decline
# interest NOUN compound rates
# rates NOUN pobj in
# , PUNCT punct decline
# as ADP mark expected
# expected VERB advcl decline
# by ADP agent expected
# some DET pobj by
# in ADP prep some
# the DET det markets
# financial ADJ amod markets
# markets NOUN pobj in
# , PUNCT punct decline
# would VERB aux risk
# risk VERB ROOT risk
# reigniting VERB amod spending
# spending NOUN dobj risk
# and CCONJ cc spending
# hence ADV advmod pressures
# inflation NOUN compound pressures
# pressures NOUN conj spending
# . PUNCT punct risk
# " PUNCT punct risk

# %%
for ent in doc.ents:
    print(ent, ent.label_)
# Out:
# OCR ORG
# 7.25 percent PERCENT
# Reserve Bank ORG
# Alan Bollard PERSON
# recent months DATE
# December DATE
#
#  GPE
# the third quarter of 2005 DATE
#
#  GPE
# 2006 DATE
#
#  GPE
#
#  GPE
# recent years DATE
#
#  GPE
#
#  GPE
# Annual DATE
# 3.2 percent PERCENT
# the next couple of years DATE
#
#  GPE
#
#  GPE
# OCR ORG
#
#  GPE
# OCR ORG
#
#  GPE

# %% [markdown]
# ### The name entity recognition is mislabeling the Official Cash Rate as an organization and labeling GPE (Geopolitical entity) incorrectly.

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">The Official Cash Rate (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     OCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) will remain unchanged at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7.25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# .</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reserve Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Governor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Alan Bollard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said: "The economy has continued to slow in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     recent months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , broadly in line with the outlook contained in our
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     December
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Monetary Policy Statement.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# GDP growth slowed in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the third quarter of 2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , due to the impact of the high exchange rate on the export and import-competing sectors, and a fall in construction.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# Looking to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , while there are some early indications, we are yet to see hard evidence of a sustained slowdown in domestic demand.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# To date, strong domestic demand has been fuelled by strong employment, wage growth, rising house prices, and growth in Government spending.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# Overall, total spending continues to outstrip growth in production, contributing to an unsustainably large current account deficit.</br></br>"Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     recent years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , considerable pressures have built up on resources, leading to the current high level of inflation.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# While capacity and resource constraints appear now to be easing, inflation pressures remain of concern.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  CPI inflation stands at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3.2 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , and our forecasts point to inflation remaining toward the upper end of the target band over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-dec
